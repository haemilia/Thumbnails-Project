# %%
import pandas as pd
import urllib.request
from PIL import Image

# %%
import os

new_dir_path = "/Users/sea/YBIGTAlab/project0/git0/img/"
os.makedirs(new_dir_path, exist_ok=True)

# %%
df = pd.read_csv('/Users/sea/YBIGTAlab/project0/git0/datasets/thumbnail_csv/ITSub잇섭.csv', index_col=0)

# %%
cd git0/datasets/thumbnail_img/itsub_hd
# Out:
# [Errno 2] No such file or directory: 'git0/datasets/thumbnail_img/itsub_hd'
# /Users/sea/YBIGTAlab/project0/git0/datasets/thumbnail_img/itsub_hd

# %%
#get image from url 
def url_to_img(url_lst):
    for i in range(len(url_lst)):
        img_url = url_lst[i]
        file_name = f"{i}.png"
        urllib.request.urlretrieve(img_url, file_name)
        print(f"{file_name}.png saved")

# %%
url_to_img(df['HDThumbnailUrl'])
# Out:
# 0.png.png saved
# 1.png.png saved
# 2.png.png saved
# 3.png.png saved
# 4.png.png saved
# 5.png.png saved
# 6.png.png saved
# 7.png.png saved
# 8.png.png saved
# 9.png.png saved
# 10.png.png saved
# 11.png.png saved
# 12.png.png saved
# 13.png.png saved
# 14.png.png saved
# 15.png.png saved
# 16.png.png saved
# 17.png.png saved
# 18.png.png saved
# 19.png.png saved
# 20.png.png saved
# 21.png.png saved
# 22.png.png saved
# 23.png.png saved
# 24.png.png saved
# 25.png.png saved
# 26.png.png saved
# 27.png.png saved
# 28.png.png saved
# 29.png.png saved
# 30.png.png saved
# 31.png.png saved
# 32.png.png saved
# 33.png.png saved
# 34.png.png saved
# 35.png.png saved
# 36.png.png saved
# 37.png.png saved
# 38.png.png saved
# 39.png.png saved
# 40.png.png saved
# 41.png.png saved
# 42.png.png saved
# 43.png.png saved
# 44.png.png saved
# 45.png.png saved
# 46.png.png saved
# 47.png.png saved
# 48.png.png saved
# 49.png.png saved
# 50.png.png saved
# 51.png.png saved
# 52.png.png saved
# ...
