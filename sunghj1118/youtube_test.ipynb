# %% [markdown]
# # Youtube Thumbnail Crawling

# %% [markdown]
# ### Setup

# %%
# !pip3 install --upgrade google-api-python-client
# Out:
# Collecting google-api-python-client
#   Using cached google_api_python_client-2.77.0-py2.py3-none-any.whl (11.0 MB)
# Collecting uritemplate<5,>=3.0.1
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth<3.0.0dev,>=1.19.0
#   Using cached google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Using cached google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting httplib2<1dev,>=0.15.0
#   Using cached httplib2-0.21.0-py3-none-any.whl (96 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.21.12-cp39-cp39-win_amd64.whl (527 kB)
#      -------------------------------------- 527.0/527.0 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\sungh\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.28.1)
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Using cached googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sungh\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.2.8)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\sungh\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sungh\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\sungh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.19.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sungh\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\sungh\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sungh\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sungh\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.26.11)
# Installing collected packages: uritemplate, rsa, protobuf, httplib2, cachetools, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.3.0 google-api-core-2.11.0 google-api-python-client-2.77.0 google-auth-2.16.0 google-auth-httplib2-0.1.0 googleapis-common-protos-1.58.0 httplib2-0.21.0 protobuf-4.21.12 rsa-4.9 uritemplate-4.1.1

# %%
from googleapiclient.discovery import build
from IPython.display import JSON
import pandas as pd

# %%
# insert personal API key here
api_key = ''

# %% [markdown]
# ### Channel Statistics Function

# %%
# all the channels to be seen
channel_ids = ['UCUj6rrhMTR9pipbAWBAMvUQ',]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
               }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#   channelName       views totalVideos                playlistId
# 0         침착맨  1512708980        6427  UUUj6rrhMTR9pipbAWBAMvUQ

# %% [markdown]
# ### Video ID Function

# %%
# 다음은 video id를 출력해주는 함수이다
def get_video_ids(youtube, playlist_id):
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 10
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    # 한번에 불러올 수 있는 최대 영상 수가 50개임으로 아래 코드를 통해 next page를 불러온다
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults = 50,
            pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
# 39개의 영상이 들어있는 '2023년 침착맨 정주행' 플레이리스트
playlist_id = "PLif_jr7pPZACDdM6sB6Yr_0L0VGXEjF1b"

# video id를 불러오는 함수를 위 플레이리스트를 변수로 호출
video_ids = get_video_ids(youtube, playlist_id)

# %%
# 39개의 영상 id가 출력되는것을 확인
len(video_ids)
# Out:
# 39

# %% [markdown]
# ### Video Info Function

# %%
# this is the function that @haemilia created for crawling the desired youtube information

def get_video_info(youtube, video_ids):

    request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_ids
        )
    response = request.execute()

    video_info = []

    for video in response['items']:
        keep = {'Published': video['snippet']['publishedAt'],
        'ThumbnailUrl': video['snippet']['thumbnails']['default']['url'],
        'ViewCount': video['statistics']['viewCount'],
        'VideoId': video['id']}

        video_info.append(keep)

    return(pd.DataFrame(video_info))

# %%
video_df = get_video_info(youtube, video_ids)
video_df
# Out:
#                Published                                    ThumbnailUrl  \
# 0   2023-01-01T10:00:23Z  https://i.ytimg.com/vi/ysetd_r8Z9M/default.jpg
# 1   2023-01-02T10:00:09Z  https://i.ytimg.com/vi/NeTqujXzubM/default.jpg
# 34  2023-02-07T10:00:27Z  https://i.ytimg.com/vi/nRBLhMZjazk/default.jpg
# 35  2023-02-08T10:00:21Z  https://i.ytimg.com/vi/JgkdgAfTdBk/default.jpg
# 36  2023-02-09T10:00:34Z  https://i.ytimg.com/vi/mdsaZz5WVHU/default.jpg
# 37  2023-02-10T10:00:09Z  https://i.ytimg.com/vi/8hSds3puPQY/default.jpg
# 38  2023-02-11T10:00:11Z  https://i.ytimg.com/vi/PhWyC9sPF0M/default.jpg
#
#    ViewCount      VideoId
# 0     648900  ysetd_r8Z9M
# 1     650495  NeTqujXzubM
# 2    1262715  RRnO-9xfJY8
# 3    1261217  K6Pfi0yLav8
# 4    3685979  SP-LJqVgQuw
# 5    1094557  vO9sb-w1gdY
# 6    1184344  z_OdvenYnAs
# 7     677070  L2ZBNP_4m8E
# 8     618567  QAlkUzhL03U
# 9     420462  za_EbAThN1A
# 10   1140320  8PPUFdfzca0
# 11    626128  eWU7MdrVLNc
# 12   1244385  2dmZLhS-inY
# 13   1562052  cspfdOFcOsE
# 14   1756660  5l5OUajgNOA
# 15    745731  2Wkn-e7MRKo
# 16    720383  5M3y9XMZoPY
# 17   1267949  K3uVJDoFuhw
# 18    530900  tbuWAN13cqg
# 19    765525  xZyoOfiBBUw
# 20    924732  eNF2lT5s2Lc
# 21    726406  2KxEIeVNOtQ
# 22    608834  Wckcfh0Vu_E
# 23    655222  7iEB36n0iwY
# 24    490492  vagBS9UA6RE
# 25    523993  1CaLTHHsn8g
# 26    889495  w2wREDRrROk
# 27    340702  2K_q9U_PYOY
# 28    587892  cUJmNvaVE3U
# 29    469466  mNECLrVkXLY
# 30    263670  qQStxU4nC4o
# 31    475921  u6AkFjEcvf8
# 32    654703  52a69cv8t_o
# 33    531692  koeM3TRigqU
# 34    362440  nRBLhMZjazk
# 35    690444  JgkdgAfTdBk
# 36    627915  mdsaZz5WVHU
# 37    304385  8hSds3puPQY
# 38    346931  PhWyC9sPF0M

# %%
# function to create CSV file from DF
video_df.to_csv('2023.csv')

# %% [markdown]
# ## 2021 Calmdownman Playlist Crawling

# %%
# 347개의 영상이 들어있는 '2021년 침착맨 정주행' 플레이리스트
playlist_id = "PLif_jr7pPZADJ2MJ-iHlgLijM6xkCaFlo"

# video id를 불러오는 함수를 위 플레이리스트를 변수로 호출
video_ids = get_video_ids(youtube, playlist_id)

# %%
# 영상이 총 347개 저장 되었는지 확인
len(video_ids)
# Out:
# 347

# %%
# '2021년' 플레이리스트에 대한 정보 갖고오기
df = get_video_info(youtube, video_ids)
df
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4956\155574220.py in <module>
#       1 # '2021년' 플레이리스트에 대한 정보 갖고오기
# ----> 2 df = get_video_info(youtube, video_ids)
#       3 df
#
# ~\AppData\Local\Temp\ipykernel_4956\1080410936.py in get_video_info(youtube, video_ids)
#       7             id=video_ids
#       8         )
# ----> 9     response = request.execute()
#      10
#      11     video_info = []
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# ~\anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 400 when requesting https://youtube.googleapis.com/youtube/v3/videos returned "The request specifies an invalid filter parameter.". Details: "[{'message': 'The request specifies an invalid filter parameter.', 'domain': 'youtube.parameter', 'reason': 'invalidFilters', 'location': 'parameters.', 'locationType': 'other'}]">
